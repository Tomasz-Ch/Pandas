# %%
import pandas as pd
df = pd.read_csv('fte.csv')
print(df.head(5))
# Out:
#          Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen
# 0  2017-01-02    74.858     77.102     73.810      77.102    14020
# 1  2017-01-03    77.800     77.900     76.503      76.503     2055
# 2  2017-01-04    76.603     76.703     75.606      75.606     2971
# 3  2017-01-05    75.705     75.805     73.312      73.511    19547
# 4  2017-01-09    73.790     75.197     72.414      72.813    14825

# %%
print(df.tail())
# Out:
#            Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen
# 660  2019-08-27     25.00      25.20       24.5       24.95     8037
# 661  2019-08-28     25.20      25.20       24.3       24.30     1345
# 662  2019-08-29     25.00      25.00       24.2       25.00      977
# 663  2019-08-30     24.95      25.00       24.4       25.00     3335
# 664  2019-09-02     25.00      25.15       24.7       25.00      589

# %%
len(df)
# Out:
# 665

# %%
df_xls = pd.read_excel('fte.xls')
df.head(3)
# Out:
#          Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen
# 0  2017-01-02    74.858     77.102     73.810      77.102    14020
# 1  2017-01-03    77.800     77.900     76.503      76.503     2055
# 2  2017-01-04    76.603     76.703     75.606      75.606     2971

# %%
df_xlsx = pd.read_excel('fte.xlsx')
df.head(3)
# Out:
#          Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen
# 0  2017-01-02    74.858     77.102     73.810      77.102    14020
# 1  2017-01-03    77.800     77.900     76.503      76.503     2055
# 2  2017-01-04    76.603     76.703     75.606      75.606     2971

# %%
df_txt = pd.read_csv('fte.txt')
df_txt.head(3)
# Out:
#          Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen
# 0  2017-01-02    74.858     77.102     73.810      77.102    14020
# 1  2017-01-03    77.800     77.900     76.503      76.503     2055
# 2  2017-01-04    76.603     76.703     75.606      75.606     2971

# %%
print(df.columns)
# Out:
# Index(['Data', 'Otwarcie', 'Najwyzszy', 'Najnizszy', 'Zamkniecie', 'Wolumen'], dtype='object')

# %%
print(df[['Data', 'Otwarcie', 'Zamkniecie']].head(3))
# Out:
#          Data  Otwarcie  Zamkniecie
# 0  2017-01-02    74.858      77.102
# 1  2017-01-03    77.800      76.503
# 2  2017-01-04    76.603      75.606

# %%
print(df.Data.head(3))
# Out:
# 0    2017-01-02
# 1    2017-01-03
# 2    2017-01-04
# Name: Data, dtype: object

# %%
print(df.iloc[22:33])
# Out:
#           Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen
# 22  2017-02-02    82.687     82.737     81.540      82.079     2421
# 23  2017-02-03    82.987     82.987     80.992      81.291     3901
# 24  2017-02-06    81.750     83.475     81.291      81.291     3566
# 25  2017-02-07    81.491     81.491     78.957      79.845     5071
# 26  2017-02-08    79.765     81.281     78.897      81.281     4911
# 27  2017-02-09    81.281     84.952     80.124      83.785     8658
# 28  2017-02-10    83.785     84.283     83.386      83.685     1321
# 29  2017-02-13    83.785     83.785     82.777      82.787     1546
# 30  2017-02-14    82.787     82.787     81.341      81.780     2057
# 31  2017-02-15    82.039     82.189     81.301      81.870     2672
# 32  2017-02-16    82.877     82.987     79.725      81.780    10659

# %%
print(df.iloc[22:25,3:5])
# Out:
#     Najnizszy  Zamkniecie
# 22     81.540      82.079
# 23     80.992      81.291
# 24     81.291      81.291

# %% [markdown]
# #### DataFrame.iterrows

# %%
# for a, b in df.iterrows():
#     print(a, b[['Data', 'Otwarcie', 'Zamkniecie', 'Wolumen']])

# %% [markdown]
# #### DataFrame.loc

# %%
print(df.loc[df['Otwarcie'] == 83.705].head(5))
# Out:
#           Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen
# 51  2017-03-15    83.705     84.573     82.807      83.276    21202

# %%
df.describe()
# Out:
#          Otwarcie   Najwyzszy   Najnizszy  Zamkniecie        Wolumen
# count  665.000000  665.000000  665.000000  665.000000     665.000000
# mean    50.883014   51.543688   50.019734   50.767964   22189.634586
# std     20.751097   20.877764   20.580506   20.771651   45087.041625
# min     20.500000   21.000000   19.500000   20.350000     107.000000
# 25%     29.750000   30.000000   29.000000   29.500000    2832.000000
# 50%     49.900000   50.600000   48.900000   50.000000    7144.000000
# 75%     72.500000   72.970000   71.120000   72.480000   20029.000000
# max     85.271000   85.779000   83.834000   85.231000  353461.000000

# %%
df.sort_values(['Otwarcie', 'Data'], ascending=[True, 0]).head(6)
# Out:
#            Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen  Srednia
# 477  2018-11-28     20.50      22.05      20.05       20.35   250151   21.050
# 472  2018-11-21     20.55      21.00      20.30       21.00    12929   20.650
# 478  2018-11-29     20.65      21.60      20.50       21.00    13779   21.050
# 474  2018-11-23     20.70      21.00      20.70       21.00    26154   20.850
# 470  2018-11-19     20.70      22.00      20.55       21.90   129388   21.275
# 480  2018-12-03     21.00      21.70      20.55       21.70    68783   21.125

# %%
df['Srednia'] = (df['Najwyzszy'] + df['Najnizszy']) / 2

# %%
df.head(5)
# Out:
#          Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen  Srednia
# 0  2017-01-02    74.858     77.102     73.810      77.102    14020  75.4560
# 1  2017-01-03    77.800     77.900     76.503      76.503     2055  77.2015
# 2  2017-01-04    76.603     76.703     75.606      75.606     2971  76.1545
# 3  2017-01-05    75.705     75.805     73.312      73.511    19547  74.5585
# 4  2017-01-09    73.790     75.197     72.414      72.813    14825  73.8055

# %%
df.drop(columns=['Srednia']).head(4)
# Out:
#          Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen
# 0  2017-01-02    74.858     77.102     73.810      77.102    14020
# 1  2017-01-03    77.800     77.900     76.503      76.503     2055
# 2  2017-01-04    76.603     76.703     75.606      75.606     2971
# 3  2017-01-05    75.705     75.805     73.312      73.511    19547

# %%
df.drop(index=2).head(4)
# Out:
#          Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen  Srednia
# 0  2017-01-02    74.858     77.102     73.810      77.102    14020  75.4560
# 1  2017-01-03    77.800     77.900     76.503      76.503     2055  77.2015
# 3  2017-01-05    75.705     75.805     73.312      73.511    19547  74.5585
# 4  2017-01-09    73.790     75.197     72.414      72.813    14825  73.8055

# %%
srednia_por = df['Srednia_por'] = df.iloc[:, 2:4].mean(axis=1)
df.head(5)
# Out:
#          Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen  Srednia  \
# 0  2017-01-02    74.858     77.102     73.810      77.102    14020  75.4560
# 1  2017-01-03    77.800     77.900     76.503      76.503     2055  77.2015
# 2  2017-01-04    76.603     76.703     75.606      75.606     2971  76.1545
# 3  2017-01-05    75.705     75.805     73.312      73.511    19547  74.5585
# 4  2017-01-09    73.790     75.197     72.414      72.813    14825  73.8055
#
#    Srednia_por
# 0      75.4560
# 1      77.2015
# 2      76.1545
# 3      74.5585
# 4      73.8055

# %%
df.columns
# Out:
# Index(['Data', 'Otwarcie', 'Najwyzszy', 'Najnizszy', 'Zamkniecie', 'Wolumen',
#        'Srednia', 'Srednia_por'],
#       dtype='object')

# %%
cols = list(df.columns)
cols
# Out:
# ['Data',
#  'Otwarcie',
#  'Najwyzszy',
#  'Najnizszy',
#  'Zamkniecie',
#  'Wolumen',
#  'Srednia',
#  'Srednia_por']

# %%
new_df = df[cols[:4] + [cols[-2]] + cols[4:6] + [cols[-1]]]

new_df.head(5)
# Out:
#          Data  Otwarcie  Najwyzszy  Najnizszy  Srednia  Zamkniecie  Wolumen  \
# 0  2017-01-02    74.858     77.102     73.810  75.4560      77.102    14020
# 1  2017-01-03    77.800     77.900     76.503  77.2015      76.503     2055
# 2  2017-01-04    76.603     76.703     75.606  76.1545      75.606     2971
# 3  2017-01-05    75.705     75.805     73.312  74.5585      73.511    19547
# 4  2017-01-09    73.790     75.197     72.414  73.8055      72.813    14825
#
#    Srednia_por
# 0      75.4560
# 1      77.2015
# 2      76.1545
# 3      74.5585
# 4      73.8055

# %%
new_df.to_csv('modified.csv', index=False)

# %%
new_df.to_excel('modified.xlsx', index=False)

# %%
new_df.to_csv('modified.txt', index=False, sep='\t')

# %%
a = pd.read_csv('modified.txt', delimiter= "\t")

# %% [markdown]
# ## Filtrowanie

# %%
a = df['Otwarcie'] == 25 
b = df['Data'] == '2019-08-20'

# %%
df.loc[a & b]
# Out:
#            Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen  Srednia  \
# 655  2019-08-20      25.0       25.2      24.35        24.9     2832   24.775
#
#      Srednia_por
# 655       24.775

# %%
df.loc[(df['Otwarcie'] == 25) & (df['Data'] == '2019-08-20')]
# Out:
#            Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen  Srednia  \
# 655  2019-08-20      25.0       25.2      24.35        24.9     2832   24.775
#
#      Srednia_por
# 655       24.775

# %%
df.loc[~(df['Otwarcie'] < 25) & (df['Data'] == '2019-08-20')]  # wartiści spoza obszaru ~
# Out:
#            Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen  Srednia  \
# 655  2019-08-20      25.0       25.2      24.35        24.9     2832   24.775
#
#      Srednia_por
# 655       24.775

# %%
filtered = df.loc[(df['Otwarcie'] == 25) | (df['Data'] == '2019-08-20')]
filtered
# Out:
#            Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen  Srednia  \
# 458  2018-10-30      25.0      26.85      24.25       25.60   167188   25.550
# 462  2018-11-06      25.0      25.45      23.95       23.95   316266   24.700
# 655  2019-08-20      25.0      25.20      24.35       24.90     2832   24.775
# 660  2019-08-27      25.0      25.20      24.50       24.95     8037   24.850
# 662  2019-08-29      25.0      25.00      24.20       25.00      977   24.600
# 664  2019-09-02      25.0      25.15      24.70       25.00      589   24.925
#
#      Srednia_por
# 458       25.550
# 462       24.700
# 655       24.775
# 660       24.850
# 662       24.600
# 664       24.925

# %%
filtered = filtered.reset_index(drop=True)
filtered
# Out:
#          Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen  Srednia  \
# 0  2018-10-30      25.0      26.85      24.25       25.60   167188   25.550
# 1  2018-11-06      25.0      25.45      23.95       23.95   316266   24.700
# 2  2019-08-20      25.0      25.20      24.35       24.90     2832   24.775
# 3  2019-08-27      25.0      25.20      24.50       24.95     8037   24.850
# 4  2019-08-29      25.0      25.00      24.20       25.00      977   24.600
# 5  2019-09-02      25.0      25.15      24.70       25.00      589   24.925
#
#    Srednia_por
# 0       25.550
# 1       24.700
# 2       24.775
# 3       24.850
# 4       24.600
# 5       24.925

# %%
df.loc[(df['Otwarcie'] != 25) & (df['Data'] > '2019-08-20') & (df['Wolumen'] > 10000)]
# Out:
#            Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen  Srednia  \
# 659  2019-08-26      24.1      25.45       24.1        25.0    13126   24.775
#
#      Srednia_por
# 659       24.775

# %%
# df.loc[df['Nazwa kolumny'].str.contains('Wybrane_słowo')]  --> aby wyfiltrować rekordy z wybranym słowem w kolumnie


#Przykład z użyciem regex:
# import re
# df.loc[df['Nazwa kolumny'].str.contains('Wybrane_słowo| Drugie wybrane słowo', flags=re.I, regex=True)]
# df.loc[df['Nazwa kolumny'].str.contains('^sło[a-z]', flags=re.I, regex=True)]

# %% [markdown]
# ### Zmiany warunkowe

# %%
df.loc[df['Data'] == '2017-01-02', 'Data'] = '2022-01-02'
war = df
war.head()
# Out:
#          Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen
# 0  2022-01-02    74.858     77.102     73.810      77.102    14020
# 1  2017-01-03    77.800     77.900     76.503      76.503     2055
# 2  2017-01-04    76.603     76.703     75.606      75.606     2971
# 3  2017-01-05    75.705     75.805     73.312      73.511    19547
# 4  2017-01-09    73.790     75.197     72.414      72.813    14825

# %%
war.loc[war['Wolumen'] > 14000, ['Data', 'Zamkniecie']] = ['BRAK SESJI', 'TEST VALUE']
war.head()
# Out:
#          Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen
# 0  BRAK SESJI    74.858     77.102     73.810  TEST VALUE    14020
# 1  2017-01-03    77.800     77.900     76.503      76.503     2055
# 2  2017-01-04    76.603     76.703     75.606      75.606     2971
# 3  BRAK SESJI    75.705     75.805     73.312  TEST VALUE    19547
# 4  BRAK SESJI    73.790     75.197     72.414  TEST VALUE    14825

# %% [markdown]
# ### Grupowanie

# %%
df.groupby(['Data']).mean()
df.groupby(['Data']).mean().sort_values('Wolumen', ascending=False).head()
# Out:
#              Otwarcie  Najwyzszy  Najnizszy       Wolumen
# Data
# BRAK SESJI  45.666853  46.520118  44.594275  59228.127962
# 2019-02-13  25.100000  25.100000  23.800000  13796.000000
# 2018-11-22  21.000000  21.000000  19.500000  13781.000000
# 2018-11-29  20.650000  21.600000  20.500000  13779.000000
# 2018-12-17  22.900000  23.800000  22.250000  13764.000000

# %%
df.groupby(['Data']).sum().sort_values('Wolumen', ascending=False).head()
# Out:
#             Otwarcie  Najwyzszy  Najnizszy   Wolumen
# Data
# BRAK SESJI  9635.706   9815.745   9409.392  12497135
# 2019-02-13    25.100     25.100     23.800     13796
# 2018-11-22    21.000     21.000     19.500     13781
# 2018-11-29    20.650     21.600     20.500     13779
# 2018-12-17    22.900     23.800     22.250     13764

# %%
countt = df.groupby(['Data']).count().sort_values('Wolumen', ascending=False).head()
countt
# Out:
#             Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen
# Data
# BRAK SESJI       211        211        211         211      211
# 2018-07-23         1          1          1           1        1
# 2018-09-18         1          1          1           1        1
# 2018-09-17         1          1          1           1        1
# 2018-09-13         1          1          1           1        1

# %%
countt = df.groupby(['Data', 'Otwarcie']).count().sort_values('Wolumen', ascending=False).head()
countt
# Out:
#                      Najwyzszy  Najnizszy  Zamkniecie  Wolumen
# Data       Otwarcie
# BRAK SESJI 22.7              4          4           4        4
#            27.0              3          3           3        3
#            24.0              3          3           3        3
#            45.0              3          3           3        3
#            47.0              3          3           3        3

# %% [markdown]
# ### Working with Big data (np. 20 GB file)

# %%
for df in pd.read_csv('modified.csv', chunksize=5):
    print('Wymiary:', df.shape)
    print(df)
# Out:
# Wymiary: (5, 8)
#          Data  Otwarcie  Najwyzszy  Najnizszy  Srednia  Zamkniecie  Wolumen  \
# 0  2017-01-02    74.858     77.102     73.810  75.4560      77.102    14020
# 1  2017-01-03    77.800     77.900     76.503  77.2015      76.503     2055
# 2  2017-01-04    76.603     76.703     75.606  76.1545      75.606     2971
# 3  2017-01-05    75.705     75.805     73.312  74.5585      73.511    19547
# 4  2017-01-09    73.790     75.197     72.414  73.8055      72.813    14825
#
#    Srednia_por
# 0      75.4560
# 1      77.2015
# 2      76.1545
# 3      74.5585
# 4      73.8055
# Wymiary: (5, 8)
#          Data  Otwarcie  Najwyzszy  Najnizszy  Srednia  Zamkniecie  Wolumen  \
# 5  2017-01-10    72.813     75.705     72.813  74.2590      73.411    93285
# 6  2017-01-11    73.411     74.808     73.411  74.1095      74.618     3876
# 7  2017-01-12    74.618     74.618     74.199  74.4085      74.199      927
# ...
